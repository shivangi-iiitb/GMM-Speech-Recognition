# %%
import re
import numpy as np

#get data from the fileName passed as argument (in the same folder)
def getData(filename):
    x = list()
    y = list()
    z = list()
    
    with open(filename) as file:
        line = file.readline()
        while line:
            line = line.strip()
            st = line.split(" ")
            if len(st) == 3:
                x.append(st[0])
                y.append(st[1])
                z.append(st[2])
            elif len(st) == 1:
                x.append("-1")
                y.append("-1")
                z.append("-1")
            line = file.readline()
    return x,y,z

train_words,train_POS_tags,train_chunking_tags = getData('train.txt')
test_words,test_POS_tags,test_chunking_tags = getData('test.txt')

print('Train-Set size: ' + str(len(train_words)))
print('Test-Set size: ' + str(len(test_words)))
# Out:
# Train-Set size: 220663
# Test-Set size: 49389

# %%
#dictionary of tags
dic = {}
dic[0] = "#"
dic[1] = "$"
dic[2] = "''"
dic[3] = "("
dic[4] = ")"
dic[5] = ","
dic[6] = "."
dic[7] = ":"
dic[8] = "CC"
dic[9] = "CD"
dic[10] = "DT"
dic[11] = "EX"
dic[12] = "FW"
dic[13] = "IN"
dic[14] = "JJ"
dic[15] = "JJR"
dic[16] = "JJS"
dic[17] = "MD"
dic[18] = "NN"
dic[19] = "NNP"
dic[20] = "NNPS"
dic[21] = "NNS"
dic[22] = "PDT"
dic[23] = "POS"
dic[24] = "PRP"
dic[25] = "PRP$"
dic[26] = "RB"
dic[27] = "RBR"
dic[28] = "RBS"
dic[29] = "RP"
dic[30] = "SYM"
dic[31] = "TO"
dic[32] = "UH"
dic[33] = "VB"
dic[34] = "VBD"
dic[35] = "VBG"
dic[36] = "VBN"
dic[37] = "VBP"
dic[38] = "VBZ"
dic[39] = "WDT"
dic[40] = "WP"
dic[41] = "WP$"
dic[42] = "WRB"
dic[43] = "``"

# %%
#getting the accuracy of the model
def getAccuracy(prediction):
    cnt = 0
    j = 0
    for i in len(prediction):
        if(test_POS_tag[j] == "-1"):
            j = j+1
            continue
        elif prediction[i] == test_POS_tag[j]:
            j = j+1
            cnt = cnt+1
    return cnt/len(prediction)

# %%
#for getting a feature vector
def getFeatures(words,index):
    feature = list()
    
    #feature.append(True)
    #feature 1: is the first letter Capitalized?
    feature.append(words[index][0].isupper())
    
    #feature 2: is it ending in "ing"?
    feature.append(words[index][-3:] == "ing")
    
    #feature 3: is it ending in "ly"?
    feature.append(words[index][-2:] == "ly")
    
    #feature 4: is the previous word "the"?
    if index > 0:
        feature.append(words[index-1] == "the")
    else:
        feature.append(False)
    
    #feature 5: does it contain a number?
    pattern = re.compile(r'\d')
    feature.append(len(pattern.findall(words[index])) > 0)
    
    #featre 6: does it have a hyphen?
    pattern = re.compile(r'-')
    feature.append(len(pattern.findall(words[index])) > 0)
    
    return feature

# %%
def getFeatureMatrix(words):
    matrix = list()
    size = len(words)
    
    i=0
    while i<size:
        sentence = list()
        while i<size and words[i] != "-1":
            sentence.append(words[i])
            i = i+1
        j=0
        while j < len(sentence):
            matrix.append(getFeatures(sentence,j))
            j=j+1
        i = i+1
        
    return matrix

# %%
feature_matrix = np.asarray(getFeatureMatrix(train_words))
print(feature_matrix.shape)
feature_matrix[0]
# Out:
# (211727, 6)
# array([ True, False, False, False, False, False], dtype=bool)

# %%
train_POS_tags_np = np.array(train_POS_tags)

# %%
train_POS_tags_np
# Out:
# array(['NN', 'IN', 'DT', ..., 'RB', '.', '-1'],
#       dtype='<U4')

# %%
tag_list = np.unique(train_POS_tags_np)
index = np.argwhere(tag_list=='-1')
tag_list = np.delete(tag_list,index)
tag_list
# Out:
# array(['#', '$', "''", '(', ')', ',', '.', ':', 'CC', 'CD', 'DT', 'EX',
#        'FW', 'IN', 'JJ', 'JJR', 'JJS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS',
#        'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO',
#        'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$',
#        'WRB', '``'],
#       dtype='<U4')

# %%
tag_to_int = dict((c,i) for i,c in enumerate(tag_list))
int_to_tag = dict((i,c) for i,c in enumerate(tag_list))
print(train_POS_tags[0])
print(tag_to_int)
print(int_to_tag)
# Out:
# NN
# {'#': 0, '$': 1, "''": 2, '(': 3, ')': 4, ',': 5, '.': 6, ':': 7, 'CC': 8, 'CD': 9, 'DT': 10, 'EX': 11, 'FW': 12, 'IN': 13, 'JJ': 14, 'JJR': 15, 'JJS': 16, 'MD': 17, 'NN': 18, 'NNP': 19, 'NNPS': 20, 'NNS': 21, 'PDT': 22, 'POS': 23, 'PRP': 24, 'PRP$': 25, 'RB': 26, 'RBR': 27, 'RBS': 28, 'RP': 29, 'SYM': 30, 'TO': 31, 'UH': 32, 'VB': 33, 'VBD': 34, 'VBG': 35, 'VBN': 36, 'VBP': 37, 'VBZ': 38, 'WDT': 39, 'WP': 40, 'WP$': 41, 'WRB': 42, '``': 43}
# {0: '#', 1: '$', 2: "''", 3: '(', 4: ')', 5: ',', 6: '.', 7: ':', 8: 'CC', 9: 'CD', 10: 'DT', 11: 'EX', 12: 'FW', 13: 'IN', 14: 'JJ', 15: 'JJR', 16: 'JJS', 17: 'MD', 18: 'NN', 19: 'NNP', 20: 'NNPS', 21: 'NNS', 22: 'PDT', 23: 'POS', 24: 'PRP', 25: 'PRP$', 26: 'RB', 27: 'RBR', 28: 'RBS', 29: 'RP', 30: 'SYM', 31: 'TO', 32: 'UH', 33: 'VB', 34: 'VBD', 35: 'VBG', 36: 'VBN', 37: 'VBP', 38: 'VBZ', 39: 'WDT', 40: 'WP', 41: 'WP$', 42: 'WRB', 43: '``'}

# %%
def getLabelMatrix():
    label_matrix = np.zeros((feature_matrix.shape[0],len(tag_list)),dtype=int)
    k = 0
    for i in train_POS_tags_np:
        if i!='-1':
            label_matrix[k][tag_to_int[i]] = 1
            k = k+1
    return label_matrix

# %%
oneHot_LabelMatrix = getLabelMatrix()
oneHot_LabelMatrix[0]
print(oneHot_LabelMatrix.shape)
# Out:
# (211727, 44)

# %%
import sys
import numpy

numpy.seterr(all='ignore')
 

def softmax(x):
    e = numpy.exp(x - numpy.max(x))  # prevent overflow
    if e.ndim == 1:
        return e / numpy.sum(e, axis=0)
    else:  
        return e / numpy.array([numpy.sum(e, axis=1)]).T  # ndim = 2"""


class LogisticRegression(object):
    def __init__(self, input, label, n_in, n_out):
        self.x = input
        self.y = label
        self.W = numpy.zeros((n_in, n_out))  # initialize W 0
        self.b = numpy.zeros(n_out)          # initialize bias 0

        # self.params = [self.W, self.b]

    def train(self, lr, input=None, L2_reg=0.00):
        if input is not None:
            self.x = input

        # p_y_given_x = sigmoid(numpy.dot(self.x, self.W) + self.b)
        p_y_given_x = softmax(numpy.dot(self.x, self.W) + self.b)
        d_y = self.y - p_y_given_x
        
        self.W += lr * numpy.dot(self.x.T, d_y) - lr * L2_reg * self.W
        self.b += lr * numpy.mean(d_y, axis=0)
        
        # cost = self.negative_log_likelihood()
        # return cost

    def negative_log_likelihood(self):
       
        sigmoid_activation = softmax(numpy.dot(self.x, self.W) + self.b)

        cross_entropy = - numpy.mean(
            numpy.sum(self.y * numpy.log(sigmoid_activation) +
            (1 - self.y) * numpy.log(1 - sigmoid_activation),axis=1))

        return cross_entropy


    def predict(self, x):
       
        return softmax(numpy.dot(x, self.W) + self.b)


def test_lr(x , y , w_row, w_col, learning_rate=0.01, n_epochs=50):
   
    
    # construct LogisticRegression
    classifier = LogisticRegression(input=x, label=y, n_in=w_row, n_out=w_col)
    # train
    for epoch in range(n_epochs):
        classifier.train(lr=learning_rate)
        cost = classifier.negative_log_likelihood()
        print(sys.stderr, 'Training epoch %d, cost is ' % epoch, cost)
        learning_rate *= 0.95

    z = x.dot(classifier.W) + classifier.b
    normal = softmax(z)
    return normal
    

initial_softmax= test_lr(feature_matrix, oneHot_LabelMatrix, feature_matrix.shape[1], len(tag_list))
# Out:
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 0, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 1, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 2, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 3, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 4, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 5, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 6, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 7, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 8, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 9, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 10, cost is  10.0782214966
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 11, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 12, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 13, cost is  7.73645045221
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 14, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 15, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 16, cost is  8.86067881713
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 17, cost is  8.14600176788
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 18, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 19, cost is  9.24776602345
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 20, cost is  6.8246702022
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 21, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 22, cost is  8.69584124527
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 23, cost is  7.66523778254
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 24, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 25, cost is  9.08326012498
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 26, cost is  6.89932423753
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 27, cost is  8.47663086367
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 28, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 29, cost is  7.36021564292
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 30, cost is  7.21293319492
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 31, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 32, cost is  7.61245762776
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 33, cost is  6.28496902593
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 34, cost is  inf
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 35, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 36, cost is  6.8261761541
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 37, cost is  5.50828523878
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 38, cost is  5.68809682479
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 39, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 40, cost is  6.87242293478
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 41, cost is  5.84717130131
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 42, cost is  4.88100701756
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 43, cost is  5.02910127753
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 44, cost is  6.04348375419
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 45, cost is  5.25448352145
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 46, cost is  4.54680995613
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 47, cost is  4.63178077564
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 48, cost is  5.42050335126
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 49, cost is  4.80333870994

# %%
train_POS_pair_tags = list()
train_POS_pair_tags.append(train_POS_tags[0])
for i in range(1,len(train_POS_tags)):
    if(train_POS_tags[i-1]=='-1'):
        train_POS_pair_tags.append(train_POS_tags[i])
    elif(train_POS_tags[i]!='-1'):
        train_POS_pair_tags.append(train_POS_tags[i-1]+train_POS_tags[i])
    
print(train_POS_pair_tags)
# Out:
# ['NN', 'NNIN', 'INDT', 'DTNN', 'NNVBZ', 'VBZRB', 'RBVBN', 'VBNTO', 'TOVB', 'VBDT', 'DTJJ', 'JJNN', 'NNIN', 'INNN', 'NNNNS', 'NNSIN', 'INNNP', 'NNP,', ',JJ', 'JJIN', 'INNN', 'NNNN', 'NN,', ',VB', 'VBTO', 'TOVB', 'VBDT', 'DTJJ', 'JJNN', 'NNIN', 'INNNP', 'NNPCC', 'CCNNP', 'NNPPOS', 'POSJJ', 'JJNNS', 'NNS.', 'NNP', 'NNPIN', 'INDT', 'DTNNP', 'NNPNNP', 'NNPNNP', 'NNPPOS', 'POSVBN', 'VBNNN', 'NNTO', 'TODT', 'DTNN', 'NNJJ', 'JJNN', 'NNVBZ', 'VBZVBN', 'VBNTO', 'TOVB', 'VBDT', 'DTNN', 'NNIN', 'INNN', 'NNIN', 'INDT', 'DTJJ', 'JJNN', 'NN.', 'CC', 'CCNNS', 'NNSVBP', 'VBPVBG', 'VBGNN', 'NNIN', 'INNN', 'NNVBZ', 'VBZVBN', 'VBNVBN', 'VBNIN', 'INDT', 'DTNN', 'NNPOS', 'POSNN', 'NNTO', 'TOVB', 'VBDT', 'DTJJ', 'JJNN', 'NNNNS', 'NNSIN', 'INPRP$', 'PRP$NNP', 'NNPNNP', 'NNPNN', 'NNJJ', 'JJNNP', 'NNP.', 'DT', 'DTVBZ', 'VBZVBN', 'VBNDT', 'DTNN', 'NNIN', 'INDT', 'DTNN', 'NNVBG', 'VBGVBN', 'VBNTO', 'TOVB', 'VBNN', 'NNNNS', 'NNSTO', 'TOCD', 'CDNN', 'NNIN', 'INPRP$', 'PRP$JJ', 'JJCD', 'CDNN', 'NNNN', 'NNTO', 'TOVB', 'VBDT', 'DTNN', 'NN,', ',NNS', 'NNSCC', 'CCJJ', 'JJNN', 'NNNN', 'NNNNS', 'NNSVBP', 'VBP.', '``', '``DT', 'DTNNS', 'NNSIN', 'INNN', 'NNIN', 'INDT', 'DTJJ', 'JJNN', 'NNNN', 'NNVBP', 'VBPRB', 'RBRB', 'RBIN', 'INDT', 'DTJJ', 'JJNN', 'NN,', ",''", "''VBD", 'VBDNNP', 'NNPNNP', 'NNP,', ',JJ', 'JJNNP', 'NNPNN', 'NNIN', 'INNNP', 'NNPNNP', 'NNPNNP', 'NNP.', '``', '``IN', 'INEX', 'EXVBZ', 'VBZDT', 'DTJJ', 'JJNN', 'NNNN', 'NN,', ',EX', 'EXMD', 'MDVB', 'VBDT', 'DTJJ', 'JJNN', 'NNIN', 'INNN', 'NN,', ",''", "''VBD", 'VBDNNP', 'NNPNNP', 'NNP,', ',NNP', 'NNPNN', 'NNIN', 'INNNP', 'NNPNNP', 'NNP,', ',DT', 'DTNN', 'NNIN', 'INNNP', 'NNPNNP', 'NNPNNP', 'NNP.', 'NNS', 'NNSIN', 'INDT', 'DTNN', 'NNNNS', 'NNSVBP', 'VBPRB', 'RB,', ',CC', 'CCJJ', 'JJNNS', 'NNSVBP', 'VBPDT', 'DTNNS', 'NNSTO', 'TOVB', 'VBDT', 'DTRB', 'RBVBN', 'VBNNN', 'NNIN', 'INDT', 'DT#', '#CD', 'CDCD', 'CD(', '($', '$CD', 'CDCD', 'CD)', ')NN', 'NNIN', 'INDT', 'DTJJ', 'JJNN', 'NNVBD', 'VBDIN', 'INNNP', 'NNP.', 'DT', 'DTNNP', 'NNPNN', 'NNCC', 'CCDT', 'DT#', '#CD', 'CDCD', 'CDNN', 'NNVBN', 'VBNIN', 'INNNP', 'NNPVBP', 'VBPVBN', 'VBNRB', 'RBIN', 'INDT', 'DT#', '#CD', 'CDCD', 'CDNN', 'NNIN', 'INNNP', 'NNPCD', 'CD.', 'NNP', 'NNPNNP', 'NNP,', ',JJ', 'JJNN', 'NNIN', 'INNNP', 'NNPNNPS', 'NNPSCC', 'CCNNP', 'NNP,', ',VBD', 'VBDEX', 'EXVBZ', 'VBZDT', 'DTNN', 'NNIN', 'INNNP', 'NNPPOS', 'POSNN', 'NNNN', 'NNVBZ', 'VBZVBG', 'VBGPRP', 'PRPTO', 'TOVB', 'VBNNS', 'NNS.', 'IN', 'INDT', 'DTJJ', 'JJNN', 'NN,', ',PRP', 'PRPVBZ', 'VBZRB', 'RBJJ', 'JJIN', 'INDT', 'DTNN', 'NNIN', 'INNNS', 'NNS,', ',VBN', 'VBNVBD', 'VBDJJ', 'JJNN', 'NNCC', 'CCNN', 'NNNNS', 'NNSNNS', 'NNS.', 'PRP', 'PRPVBZ', 'VBZDT', 'DTJJ', 'JJNN', 'NNNN', 'NNMD', 'MDVB', 'VBTO', 'TORB', 'RB#', '#CD', 'CDCD', 'CDIN', 'INNNP', 'NNP.', 'RB', 'RB,', ',NNP', 'NNPNNP', 'NNPVBD', 'VBDPRP', 'PRPVBZ', 'VBZIN', 'INDT', 'DTNN', 'NNIN', 'INJJ', 'JJNN', 'NNVBG', 'VBGIN', 'INNN', 'NNMD', 'MDVB', 'VBTO', 'TODT', 'DTJJ', 'JJNN', 'NNIN', 'INNNS', 'NNS.', 'VBN', 'VBNIN', 'ININ', 'INJJS', 'JJSDT', 'DTNN', 'NNIN', 'INNNS', 'NNSIN', 'INNNP', 'NNPPOS', 'POSJJ', 'JJNN', 'NN,', ',DT', 'DTNN', 'NNMD', 'MDVB', 'VBTO', 'TORB', 'RBJJ', 'JJIN', 'IN#', '#CD', 'CDCD', 'CD.', 'NNP', 'NNPNNP', 'NNP,', ',WP', 'WPRB', 'RBVBZ', 'VBZDT', 'DT#', '#CD', 'CDCD', 'CDJJ', 'JJNN', 'NNNN', 'NN,', ',VBZ', 'VBZIN', 'INRB', 'RBIN', 'INDT', 'DTNN', 'NNNNS', 'NNSVBP', 'VBPJJ', 'JJIN', 'INNN', 'NN,', ',DT', 'DTNN', 'NNMD', 'MDRB', 'RBVB', 'VBJJ', 'JJIN', 'INNNS', 'NNSMD', 'MDVB', 'VBTO', 'TOVB', 'VBJJ', 'JJNN', 'NNIN', 'INDT', 'DTNN', 'NNIN', 'INVBG', 'VBGNNS', 'NNS.', 'RB', 'RB,', ',PRP', 'PRPVBD', 'VBD,', ',``', '``DT', 'DTPRP', 'PRPMD', 'MDVB', 'VBTO', 'TOVB', 'VBIN', 'INDT', 'DTNN', 'NNNNS', 'NNSIN', 'INDT', 'DTJJ', 'JJNN', "NN''", "''IN", 'INDT', 'DTNN', 'NN.', 'RB', 'RB,', ',JJ', 'JJNN', 'NNIN', 'INDT', 'DTNN', 'NNVBZ', 'VBZRB', 'RBVBN', 'VBN.', 'IN', 'INPRP$', 'PRP$NNP', 'NNPNNP', 'NNPNN', 'NN,', ',NNP', 'NNPNNP', 'NNPVBD', 'VBDIN', 'INDT', 'DTJJ', 'JJNN', 'NNMD', 'MDVB', 'VBVBN', 'VBNIN', 'INDT', 'DTNN', ' ...

# %%
train_POS_pair_tags_np = np.array(train_POS_pair_tags)
train_POS_pair_tags_unique = np.unique(train_POS_pair_tags_np)
pair_tag_to_int = dict((c,i) for i,c in enumerate(train_POS_pair_tags_unique))
int_to_tag_pair = dict((i,c) for i,c in enumerate(train_POS_pair_tags_unique))

#print(pair_tag_to_int)
#print(int_to_tag_pair)
len(train_POS_pair_tags_np)
# Out:
# 211727

# %%
def getLabelMatrix1():
    label_matrix = np.zeros((feature_matrix.shape[0],len(train_POS_pair_tags_unique)),dtype=int)
    k = 0
    for i in train_POS_pair_tags_np:
        label_matrix[k][pair_tag_to_int[i]] = 1
        k = k+1
    return label_matrix

oneHot_pair_LabelMatrix = getLabelMatrix1()

# %%
second_softmax= test_lr(feature_matrix, oneHot_pair_LabelMatrix, feature_matrix.shape[1], len(train_POS_pair_tags_unique))
second_softmax
# Out:
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 0, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 1, cost is  20.6129552938
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 2, cost is  18.1954518465
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 3, cost is  17.9934973746
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 4, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 5, cost is  21.8902197094
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 6, cost is  21.3942015352
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 7, cost is  16.9991396154
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 8, cost is  nan
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 9, cost is  17.6993295621
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 10, cost is  15.3320313594
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 11, cost is  13.5223334331
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 12, cost is  19.0686262162
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 13, cost is  16.4136493131
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 14, cost is  14.4523237525
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 15, cost is  17.140913664
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 16, cost is  14.7509485091
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 17, cost is  12.5702767584
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 18, cost is  12.6258790007
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 19, cost is  12.9249823979
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 20, cost is  10.6091425146
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 21, cost is  9.52168032306
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 22, cost is  12.6473800534
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 23, cost is  13.531290863
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 24, cost is  11.1683562477
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 25, cost is  10.6780260303
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 26, cost is  11.567222021
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 27, cost is  10.3771556055
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 28, cost is  9.12365455111
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 29, cost is  9.68374831432
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 30, cost is  9.39742416936
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 31, cost is  9.04210095583
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 32, cost is  8.66454446865
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 33, cost is  9.69341542097
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 34, cost is  9.17994671019
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 35, cost is  8.53028236027
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 36, cost is  8.10162593529
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 37, cost is  8.31517778385
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 38, cost is  7.8088989079
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 39, cost is  8.55945611178
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 40, cost is  8.30507680971
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 41, cost is  7.97573596043
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 42, cost is  7.66234540629
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 43, cost is  7.75221170855
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 44, cost is  7.58998283778
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 45, cost is  7.83354327161
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 46, cost is  7.58608939511
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 47, cost is  7.80481277298
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 48, cost is  7.83608006829
# <ipykernel.iostream.OutStream object at 0x000001CB7792E630> Training epoch 49, cost is  7.58610314085
# array([[  7.57736833e-05,   7.57531195e-05,   7.57740092e-05, ...,
#           1.08966273e-04,   4.49272174e-04,   5.32368458e-04],
#        [  8.87198365e-04,   8.87214988e-04,   8.87202233e-04, ...,
#           8.87199887e-04,   8.87205049e-04,   8.87208854e-04],
#        [  8.87198365e-04,   8.87214988e-04,   8.87202233e-04, ...,
#           8.87199887e-04,   8.87205049e-04,   8.87208854e-04],
#        ...,
#        [  7.57736833e-05,   7.57531195e-05,   7.57740092e-05, ...,
#           1.08966273e-04,   4.49272174e-04,   5.32368458e-04],
#        [  8.87198365e-04,   8.87214988e-04,   8.87202233e-04, ...,
#           8.87199887e-04,   8.87205049e-04,   8.87208854e-04],
#        [  8.87198365e-04,   8.87214988e-04,   8.87202233e-04, ...,
#           8.87199887e-04,   8.87205049e-04,   8.87208854e-04]])
